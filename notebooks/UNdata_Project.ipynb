# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('..\data\gdp_percapita.csv')

# %% [markdown]
# #5 - How many rows and columns are in gdp_df? What are the data types of each column? 7176 rows and 3 columns

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %% [markdown]
# #6 - Drop the Value Footnotes column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %% [markdown]
# #7 How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?

# %%
gdp_df.drop(column=['Value Footnotes'])

gdp_df.rename(column={'Country or Area':'Country','Value':'GDP_Per_Capita'})

# %%
gdp_df['Country'].value_counts().sort_values().head(10)
# Out:
# Djibouti                      8
# Somalia                       8
# Turks and Caicos Islands     10
# Sint Maarten (Dutch part)    10
# Kosovo                       13
# Cayman Islands               15
# Nauru                        17
# Afghanistan                  19
# Ṣo Tom̩ and Principe      20
# Other small states           21
# Name: Country, dtype: int64

# %% [markdown]
# #8 In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %%
plt.plot(gdp_df.GDP_Per_Capita,label="2020")
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.hist(gdp_df.GDP_Per_Capita,label="2020",range=(0, 120000))
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
boxplot=gdp_df.boxplot(column=['GDP_Per_Capita','Year'])

# %%
gdp_df.median(Year'2020)
# Out:
#   Cell In[131], line 1
#     gdp_df.median(Year'2020)
#                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
gdp_df.
